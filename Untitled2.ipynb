# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from PIL import Image
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
import warnings
import os
import shutil
from PIL import ImageFile
warnings.simplefilter('error', Image.DecompressionBombWarning)
ImageFile.LOAD_TRUNCATED_IMAGES = True
Image.MAX_IMAGE_PIXELS = 1000000000
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
import cv2
import os
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.checkpoint_management has been moved to tensorflow.python.checkpoint.checkpoint_management. The old module will be deleted in version 2.9.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base_delegate has been moved to tensorflow.python.trackable.base_delegate. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.python_state has been moved to tensorflow.python.trackable.python_state. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.

# %%
google_colab_flag = False

# For training in Google Colab
if(google_colab_flag):
    from google.colab import drive
    drive.mount('/content')
    # !ls
    import sys
    
    root_path = 'keras'
    sys.path.append(root_path)

else:
    root_path = ''

# %%
from zipfile import ZipFile
data="cobre_data.zip"
with ZipFile(data,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
dataset_folder_name = os.path.join(root_path, 'cobre_data')
MODEL_FILENAME = root_path+"model_cv.h5"
source_files = []
class_labels = ['nz', 'sz']
X = []
Y = []

img_rows, img_cols = 64, 64  # input image dimensions
train_path = os.path.join(dataset_folder_name, 'train')
validation_path = os.path.join(dataset_folder_name, 'validation')
test_path = os.path.join(dataset_folder_name, 'test')

# %%
def transfer_between_folders(source, dest, split_rate):
    """ Based on the split ratio this function moves some portion of the source folder to destination folder!

        Args:
            source: str
                Source folder's path
            dest: str
                Destination folder's path
            split_rate: float
                Ratio of files to move from source to dest locaiton

    """
    global source_files
    source_files = os.listdir(source)
    if(len(source_files) != 0):
        transfer_file_numbers = int(len(source_files)*split_rate)
        transfer_index = random.sample(
            range(0, len(source_files)), transfer_file_numbers)
        for each_index in transfer_index:
            shutil.move(os.path.join(source, str(source_files[each_index])), os.path.join(
                dest, str(source_files[each_index])))

    else:
        print("No file moved. Source empty!")


def transfer_all_class_between_folders(source, dest, split_rate):
    
    for label in class_labels:
        transfer_between_folders(os.path.join(dataset_folder_name, source, label),
                                 os.path.join(
                                     dataset_folder_name, dest, label),
                                 split_rate)


def my_metrics(y_true, y_pred):
   
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    f1_Score = f1_score(y_true, y_pred, average='weighted')
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1_Score))
    cm = confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1_Score

# %%
transfer_all_class_between_folders('test', 'train', 1.0)

# %%
transfer_all_class_between_folders('train', 'test', 0.10)

# %%
def prepare_name_with_labels(folder_name, dataset_type='train'):
    """ Prepare the file names (X) and the class labels (Y) from folder location of images.

        Args:
            folder_name: str
                Source folder's path

    """
    source_files = os.listdir(os.path.join(dataset_folder_name, dataset_type, folder_name))
    y_label = 0
    for i in range(len(class_labels)):
        if(folder_name == class_labels[i]):
            y_label = i
    for val in source_files:
        X.append(val)
        Y.append(y_label)

# %%
for i in range(len(class_labels)):
    prepare_name_with_labels(class_labels[i])

# %%
X = np.asarray(X)
Y = np.asarray(Y)

# %%
batchs_size =32
epoch = 30
num_of_channels = 1
number_of_class_labels = len(class_labels)
img_rows, img_cols = 64, 64  # input image dimensions
train_path = os.path.join(dataset_folder_name, 'train')
validation_path = os.path.join(dataset_folder_name, 'validation')
test_path = os.path.join(dataset_folder_name, 'test')

# %%
def get_model():
    activation_function = 'relu'

    model = Sequential()
    model.add(Conv2D(64, (7, 7), padding='same',
                     activation=activation_function, input_shape=(img_rows, img_cols, num_of_channels)))
    model.add(Conv2D(64, (5, 5), activation=activation_function))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(32, (3, 3), padding='same',
                     activation=activation_function))
    model.add(Conv2D(32, (3, 3), activation=activation_function))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(16, (3, 3), padding='same',
                     activation=activation_function))
    model.add(Conv2D(16, (3, 3), activation=activation_function))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(64, activation=activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(32, activation=activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(16, activation=activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(number_of_class_labels, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model


model = get_model()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        3200
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        102464
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 64)       0
#  )
#
#  dropout (Dropout)           (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        18464
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 16)        4624
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 16)        2320
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 16)          0
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 179,890
# Trainable params: 179,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ===============Stratified K-Fold======================
skf = StratifiedKFold(n_splits=10, shuffle=True)
skf.get_n_splits(X, Y)
fold_num = 0
for train_index, val_index in skf.split(X, Y):
    # First cut all images from validation to train (if any exists)
    transfer_all_class_between_folders('validation', 'train', 1.0)
    fold_num += 1
    print("Results for fold", fold_num)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    # Move validation images of this fold from train folder to the validation folder
    for each_index in range(len(X_val)):
        class_label = ''
        for i in range(len(class_labels)):
            if(Y_val[each_index] == i):
                class_label = class_labels[i]
        # Then, copy the validation images to the validation folder
        shutil.move(os.path.join(dataset_folder_name, 'train', class_label, X_val[each_index]),
                    os.path.join(dataset_folder_name, 'validation', class_label, X_val[each_index]))

    train_datagen = ImageDataGenerator(
        rescale=1./255,
        zoom_range=0.20,
        fill_mode="nearest")
    validation_datagen = ImageDataGenerator(rescale=1./255)
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Start ImageClassification Model
    train_generator = train_datagen.flow_from_directory(train_path,

        target_size=(img_rows, img_cols),
        color_mode='grayscale',                                               
        batch_size=batchs_size,
        class_mode='categorical',
        subset='training')

    validation_generator = validation_datagen.flow_from_directory(
        validation_path,
        color_mode='grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batchs_size,
        class_mode=None,  # only data, no labels
        shuffle=False)

    # fit model
    history = model.fit(train_generator,validation_data=validation_generator,epochs=epoch)
    #validation_data=validation_generator
   
    #steps_per_epoch=100,
    #validation_steps=None,
    

    predictions = model.predict(validation_generator, verbose=1)
    y_predictions = np.argmax(predictions, axis=1)
    true_classes = validation_generator.classes
    
    # evaluate validation performance
    print("***Performance on Validation data***")
    val_acc, val_prec, val_fScore = my_metrics(true_classes, y_predictions)
# Out:
# Results for fold 1
# Found 1719 images belonging to 2 classes.
# Found 187 images belonging to 2 classes.
# Epoch 1/30
# 54/54 [==============================] - 37s 650ms/step - loss: 0.6945 - accuracy: 0.4997 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 54/54 [==============================] - 27s 500ms/step - loss: 0.6933 - accuracy: 0.5271 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.6777 - accuracy: 0.5864 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 54/54 [==============================] - 27s 499ms/step - loss: 0.2369 - accuracy: 0.9122 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.1350 - accuracy: 0.9651 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 54/54 [==============================] - 28s 511ms/step - loss: 0.1057 - accuracy: 0.9727 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 54/54 [==============================] - 27s 499ms/step - loss: 0.0892 - accuracy: 0.9744 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0823 - accuracy: 0.9825 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 54/54 [==============================] - 27s 507ms/step - loss: 0.0604 - accuracy: 0.9884 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 54/54 [==============================] - 28s 511ms/step - loss: 0.0678 - accuracy: 0.9872 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 54/54 [==============================] - 28s 524ms/step - loss: 0.0583 - accuracy: 0.9884 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 54/54 [==============================] - 28s 510ms/step - loss: 0.0747 - accuracy: 0.9860 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 54/54 [==============================] - 28s 517ms/step - loss: 0.0743 - accuracy: 0.9878 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 54/54 [==============================] -
- accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0453 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 54/54 [==============================] - 28s 512ms/step - loss: 0.0397 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0393 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 54/54 [==============================] - 27s 505ms/step - loss: 0.0459 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 54/54 [==============================] - 27s 495ms/step - loss: 0.0457 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 54/54 [==============================] - 27s 500ms/step - loss: 0.0435 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 54/54 [==============================] - 27s 495ms/step - loss: 0.0418 - accuracy: 0.9895 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 54/54 [==============================] - 27s 500ms/step - loss: 0.0448 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0382 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 54/54 [==============================] - 27s 495ms/step - loss: 0.0426 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0438 - accuracy: 0.9895 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# 6/6 [==============================] - 0s 63ms/step
# ***Performance on Validation data***
# Accuracy  : 1.0
# Precision : 1.0
# f1Score : 1.0
# [[94  0]
#  [ 0 92]]
# Results for fold 9
# Found 1720 images belonging to 2 classes.
# Found 186 images belonging to 2 classes.
# Epoch 1/30
# 54/54 [==============================] - 27s 505ms/step - loss: 0.0355 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0401 - accuracy: 0.9924 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0364 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0348 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0356 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 54/54 [==============================] - 27s 495ms/step - loss: 0.0423 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0383 - accuracy: 0.9924 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 54/54 [==============================] - 27s 500ms/step - loss: 0.0345 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 54/54 [==============================] - 27s 501ms/step - loss: 0.0308 - accuracy: 0.9936 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0335 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0394 - accuracy: 0.9924 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0322 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0381 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0376 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0390 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 54/54 [==============================] - 27s 494ms/step - loss: 0.0393 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0408 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0372 - accuracy: 0.9924 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0344 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0379 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 54/54 [==============================] - 28s 509ms/step - loss: 0.0340 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 54/54 [==============================] - 27s 499ms/step - loss: 0.0418 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 54/54 [==============================] - 28s 516ms/step - loss: 0.0314 - accuracy: 0.9924 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 54/54 [==============================] - 27s 500ms/step - loss: 0.0311 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 54/54 [==============================] - 27s 505ms/step - loss: 0.0340 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 54/54 [==============================] - 28s 511ms/step - loss: 0.0374 - accuracy: 0.9936 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0333 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 54/54 [==============================] - 27s 507ms/step - loss: 0.0331 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 54/54 [==============================] - 28s 515ms/step - loss: 0.0363 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0350 - accuracy: 0.9930 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# 6/6 [==============================] - 0s 60ms/step
# ***Performance on Validation data***
# Accuracy  : 0.9838709677419355
# Precision : 0.983928777893398
# f1Score : 0.9838714339663106
# [[92  2]
#  [ 1 91]]
# Results for fold 10
# Found 1720 images belonging to 2 classes.
# Found 186 images belonging to 2 classes.
# Epoch 1/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0541 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0372 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0460 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0425 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0421 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 54/54 [==============================] - 27s 493ms/step - loss: 0.0386 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0377 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 54/54 [==============================] - 27s 490ms/step - loss: 0.0412 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 54/54 [==============================] - 27s 493ms/step - loss: 0.0511 - accuracy: 0.9890 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 54/54 [==============================] - 27s 499ms/step - loss: 0.0343 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 54/54 [==============================] - 27s 493ms/step - loss: 0.0491 - accuracy: 0.9890 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0391 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0405 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0383 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0571 - accuracy: 0.9901 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0464 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0468 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0453 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0385 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 54/54 [==============================] - 26s 491ms/step - loss: 0.0365 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 54/54 [==============================] - 27s 490ms/step - loss: 0.0368 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0348 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 54/54 [==============================] - 26s 490ms/step - loss: 0.0423 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 54/54 [==============================] - 27s 492ms/step - loss: 0.0368 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 54/54 [==============================] - 26s 490ms/step - loss: 0.0370 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 54/54 [==============================] - 26s 490ms/step - loss: 0.0382 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 54/54 [==============================] - 26s 490ms/step - loss: 0.0350 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0362 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0385 - accuracy: 0.9919 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 54/54 [==============================] - 27s 491ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# 6/6 [==============================] - 0s 63ms/step
# ***Performance on Validation data***
# Accuracy  : 0.9946236559139785
# Precision : 0.9946808510638298
# f1Score : 0.9946235005058535
# [[92  1]
#  [ 0 93]]

# %%
# Let's visualize the train/validation loss and accuracy wrt epochs
from PIL import Image 
import PIL 
import matplotlib.pyplot as plt 
def plot(history):
    plt.figure(1) 
     # summarize history for accuracy  
 
    plt.subplot(211)  
    plt.plot(history.history['accuracy'])  
    plt.plot(history.history['val_accuracy'])  
    plt.title('accuracy vs val_accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='lower right')  
 
     # summarize history for loss  
 
    plt.subplot(212)  
    plt.plot(history.history['loss'])  
    plt.plot(history.history['val_loss'])  
    plt.title('loss vs val_loss')  
    plt.ylabel('loss')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.tight_layout()
    plt.show()
 
# Finaly, let's call the plot function with the 'result' parameter 

 
im1=plot(history)

# %%
from keras.models import load_model
# load model
model = load_model('model_cv.h5')
acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
#       2 # load model
#       3 model = load_model('model_cv.h5')
# ----> 4 acc = model.evaluate(X_test, y_test)
#       5 print("Accuracy = ", (acc * 100.0), "%")
#
# NameError: name 'X_test' is not defined

# %%
import numpy as np
import scipy.stats as st
  
# define sample data
gfg_data = [97.86,
99.46,
99.86,
98.93,
98.93,
98.93,
99.89,
98.93,
99.46,
98.92


]
  
# create 90% confidence interval
st.t.interval(alpha=0.90, df=len(gfg_data)-1,
              loc=np.mean(gfg_data),
              scale=st.sem(gfg_data))

# %%
#ROC
from sklearn.metrics import roc_curve
y_preds = model.predict(x_test).ravel()

fpr, tpr, thresholds = roc_curve(y_test, y_preds)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'y--')
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.show()

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
print("==============TEST RESULTS============")
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(img_rows, img_cols),
    batch_size=batchs_size,
    class_mode=None,
    shuffle=False 
)
predictions = model.predict(test_generator, verbose=1)
y_predictions = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

test_acc, test_prec, test_fScore = my_metrics(true_classes, y_predictions)
model.save(MODEL_FILENAME)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
#plt.plot(history.history['val_acc'])
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","loss","Validation Loss"])
plt.show()


import matplotlib.pyplot as plt 
def plot(history):
    plt.figure(1) 
     # summarize history for accuracy  
 
    plt.subplot(211)  
    plt.plot(history.history['accuracy'])  
    #plt.plot(history.history['val_accuracy'])  
    #plt.title('accuracy vs val_accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='lower right')  
 
     # summarize history for loss  
 
    plt.subplot(212)  
    plt.plot(history.history['loss'])  
   # plt.plot(history.history['val_loss'])  
   # plt.title('loss vs val_loss')  
    plt.ylabel('loss')  
    plt.xlabel('epoch')  
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.tight_layout()
    plt.show()
 
# Finaly, let's call the plot function with the 'result' parameter 
 
plot(history)

# %%
import matplotlib.pyplot as plt 
def plot(history):
    plt.figure(1) 
     # summarize history for accuracy  
 
    plt.subplot(211)  
    plt.plot(history.history['accuracy'])  
    plt.plot(history.history['val_accuracy'])  
    plt.title('accuracy vs val_accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('epoch')  
    plt.legend(['train', 'validation'], loc='lower right')  
 
     # summarize history for loss  
 
    plt.subplot(212)  
    plt.plot(history.history['loss'])  
    plt.plot(history.history['val_loss'])  
    plt.title('loss vs val_loss')  
    plt.ylabel('loss')  
    plt.xlabel('epoch')  
    plt.legend(['train', 'validation'], loc='upper right')
    plt.tight_layout()
    plt.show()
 
# Finaly, let's call the plot function with the 'result' parameter 
 
plot(history)
